# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import ipywidgets as widgets
from ipywidgets import Layout

uploader = widgets.FileUpload(
    accept='.csv',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple=False,  # True to accept multiple files upload else False
    description="Select Pigments per Sample .csv File to Upload",
    layout=Layout(width='100%', height='50px')
)

display(uploader)
# Out:
# FileUpload(value={}, accept='.csv', description='Upload Pigments per Sample .csv File', layout=Layout(height='…

# %%
# uploader.value
#=> (
#=>   {
#=>     'name': 'example.txt',
#=>     'type': 'text/plain',
#=>     'size': 36,
#=>     'last_modified': datetime.datetime(2020, 1, 9, 15, 58, 43, 321000, tzinfo=datetime.timezone.utc),
#=>     'content': <memory at 0x10c1b37c8>
#=>   },
#=> )

# import io
# import pandas as pd
# pd.read_csv(io.BytesIO(uploader.value.content))

from chemtax.guess_taxa_from_pigments import guess_taxa_from_pigments

guess_taxa_from_pigments([], [])
# Out:
# {'bookmarks-2022-01-07.json': {'metadata': {'name': 'bookmarks-2022-01-07.json',
#    'type': 'application/json',
#    'size': 7493,
#    'lastModified': 1641537455575},
#   'content': b'{"guid":"root________","title":"","index":0,"dateAdded":1588966784182000,"lastModified":1629418986180000,"id":1,"typeCode":2,"type":"text/x-moz-place-container","root":"placesRoot","children":[{"guid":"menu________","title":"menu","index":0,"dateAdded":1588966784182000,"lastModified":1588966784443000,"id":2,"typeCode":2,"type":"text/x-moz-place-container","root":"bookmarksMenuFolder","children":[{"guid":"ty3Sw7qmy-9d","title":"Mozilla Firefox","index":0,"dateAdded":1588966784443000,"lastModified":1588966997000000,"id":7,"typeCode":2,"type":"text/x-moz-place-container","children":[{"guid":"jESBhx2z344I","title":"Help and Tutorials","index":0,"dateAdded":1588966784443000,"lastModified":1588966997000000,"id":8,"typeCode":1,"iconuri":"fake-favicon-uri:https://support.mozilla.org/en-US/products/firefox","type":"text/x-moz-place","uri":"https://support.mozilla.org/en-US/products/firefox"},{"guid":"yE-oJT5WIC5Y","title":"Customize Firefox","index":1,"dateAdded":1588966784443000,"lastModified":1588966997000000,"id":9,"typeCode":1,"iconuri":"fake-favicon-uri:https://support.mozilla.org/en-US/kb/customize-firefox-controls-buttons-and-toolbars?utm_source=firefox-browser&utm_medium=default-bookmarks&utm_campaign=customize","type":"text/x-moz-place","uri":"https://support.mozilla.org/en-US/kb/customize-firefox-controls-buttons-and-toolbars?utm_source=firefox-browser&utm_medium=default-bookmarks&utm_campaign=customize"},{"guid":"0fmLcGd_jnuq","title":"Get Involved","index":2,"dateAdded":1588966784443000,"lastModified":1588966997000000,"id":10,"typeCode":1,"iconuri":"fake-favicon-uri:https://www.mozilla.org/en-US/contribute/","type":"text/x-moz-place","uri":"https://www.mozilla.org/en-US/contribute/"},{"guid":"x9xq187P401U","title":"About Us","index":3,"dateAdded":1588966784443000,"lastModified":1588966997000000,"id":11,"typeCode":1,"iconuri":"fake-favicon-uri:https://www.mozilla.org/en-US/about/","type":"text/x-moz-place","uri":"https://www.mozilla.org/en-US/about/"}]},{"guid":"DstF-8V4Cf9P","title":"Manjaro Linux","index":1,"dateAdded":1585786669331000,"lastModified":1588966997000000,"id":13,"typeCode":2,"type":"text/x-moz-place-container","children":[{"guid":"DstB-AvM7CX9","title":"Manjaro Homepage","index":0,"dateAdded":1585786669387000,"lastModified":1588966997000000,"id":14,"typeCode":1,"type":"text/x-moz-place","uri":"https://manjaro.org/"},{"guid":"DstB-R6NByn7","title":"Manjaro Forum","index":1,"dateAdded":1585786669559000,"lastModified":1588966997000000,"id":15,"typeCode":1,"type":"text/x-moz-place","uri":"http://forum.manjaro.org/"},{"guid":"DstB-L52aHeJ","title":"Manjaro Wiki","index":2,"dateAdded":1585786669625000,"lastModified":1588966997000000,"id":16,"typeCode":1,"type":"text/x-moz-place","uri":"http://wiki.manjaro.org/index.php/Main_Page"},{"guid":"DstB-ywn9116","title":"Manjaro Downloads","index":3,"dateAdded":1585786669696000,"lastModified":1588966997000000,"id":17,"typeCode":1,"type":"text/x-moz-place","uri":"https://manjaro.org/get-manjaro/"}]},{"guid":"_bD7hTEOLHDU","title":"Ubuntu and Free Software links","index":2,"dateAdded":1567715343998000,"lastModified":1588966997000000,"id":18,"typeCode":2,"type":"text/x-moz-place-container","children":[{"guid":"Pa06Z1SRuiWE","title":"Ubuntu","index":0,"dateAdded":1567715343998000,"lastModified":1588966997000000,"id":19,"typeCode":1,"type":"text/x-moz-place","uri":"http://www.ubuntu.com/"},{"guid":"SLnBhdVtCG_5","title":"Ubuntu Wiki (community-edited website)","index":1,"dateAdded":1567715343998000,"lastModified":1588966997000000,"id":20,"typeCode":1,"type":"text/x-moz-place","uri":"http://wiki.ubuntu.com/"},{"guid":"U0wDSHvJ74rO","title":"Make a Support Request to the Ubuntu Community","index":2,"dateAdded":1567715343998000,"lastModified":1588966997000000,"id":21,"typeCode":1,"type":"text/x-moz-place","uri":"https://answers.launchpad.net/ubuntu/+addquestion"},{"guid":"7Qb5kNquy9Jr","title":"Debian (Ubuntu is based on Debian)","index":3,"dateAdded":1567715343998000 ...
